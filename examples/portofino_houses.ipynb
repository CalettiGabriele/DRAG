# %%
from src.DRAG.drag import setup, data, ask, info, slide

# %%
setup({
    "host":"",
    "model":"llama3-8b-8192",
    "api_key":""
    })

# %%
data("portofino_houses.csv")

# %%
# Code generated by DRAG
                      
import numpy as np
import pandas as pd

df = pd.read_csv('portofino_houses.csv')

# %%
ask({'df':df}, "Make a graph of the trend of houses as the surface area increases")
