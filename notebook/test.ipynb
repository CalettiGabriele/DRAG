# %% [markdown]
# # D-RAG

# %% [markdown]
# ### Import

# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.path.dirname('test.ipynb'), '..')))

from src.drag.chroma_db.chroma import ChromaDB_VectorStore
from src.drag.groq.groq_chat import Groq_Chat

# %% [markdown]
# ### Drag Model Definition

# %%
api_key = "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"

# %%
class DragModel(ChromaDB_VectorStore, Groq_Chat):
    def __init__(self, config):
        ChromaDB_VectorStore.__init__(self, config=config)
        Groq_Chat.__init__(self, config=config)

# %%
dg = DragModel(config={'api_key': api_key, 'model':'gemma-7b-it', 'dataframe':'pandas', 'dataformat':'csv'})

# %% [markdown]
# ### Data Import

# %%
dg.data(file_path='portofino.csv', df_name='df')

# %%
# Code generated by DRAG
import numpy as np
import pandas as pd

df = pd.read_csv('portofino.csv')

# %% [markdown]
# ### Drag ask()

# %% [markdown]
# ##### Data Manipulation

# %%
dg.ask(data={'df':df}, question="How many homes have a swimming pool?", context=False)
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %% [markdown]
# ##### Add Column

# %%
dg.ask(data={'df':df}, question="Return a column where you indicate with True if there are at least 3 bedrooms otherwise False", context=False)
# Out:
# "df['Three or More Bedrooms'] = df['Numero camere da letto'] >= 3"

# %% [markdown]
# ##### Draw Chart

# %%
dg.ask(data={'df':df}, question="Draw a pie chart on the Three or More Bedrooms column", context=False)
# Out:
# "import matplotlib.pyplot as plt\n\n# Get the values from the 'Three or More Bedrooms' column\nvalues = df['Three or More Bedrooms'].value_counts().values\n\n# Get the corresponding labels for the values\nlabels = df['Three or More Bedrooms'].value_counts().index\n\n# Create a pie chart\nplt.pie(values, labels=labels)\n\n# Show the plot\nplt.show()"

# %% [markdown]
# ### Drag pipe()

# %%
dg.pipe(data={'df':df},
        question="filters for houses with swimming pools;\
        then filters for houses with vista mare;\
        then selects and prints only those priced below 500000")
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# The user poses a query and you provide the python code. You answer only with python code and not with explanations. You do not respond with explanations, but only with code.
# The code you generate will be inserted inside a Python notebook, in which a Pandas DataFrame called df has already been declared.
#
# Consider the following DataFrame df:
#    ID             Indirizzo  Numero camere da letto  Numero bagni  \
# 0   1            Via Roma 1                       3             2
# 1   2   Via dei Pescatori 5                       2             1
# 2   3  Vicolo delle Rose 12                       4             3
#
# ...

# %%
# Code generated by DRAG
pool_df = df[df['Piscina']]

# %%
# Code generated by DRAG

# %%
# Code generated by DRAG
selected_df = df[(df['Prezzo (EUR)'] < 500000) & (df['Piscina'] == True) & (df['Garage'] == True)]
print(selected_df)
