# %% [markdown]
# # D-RAG

# %% [markdown]
# ### Import

# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.path.dirname('test.ipynb'), '..')))

from src.drag.chroma_db.chroma import ChromaDB_VectorStore
from src.drag.groq.groq_chat import Groq_Chat

# %% [markdown]
# ### Drag Model Definition

# %%
api_key = ""

# %%
class DragModel(ChromaDB_VectorStore, Groq_Chat):
    def __init__(self, config):
        ChromaDB_VectorStore.__init__(self, config=config)
        Groq_Chat.__init__(self, config=config)

# %%
dg = DragModel(config={'api_key': api_key, 'dataframe':'pandas', 'dataformat':'csv'})

# %% [markdown]
# ### Data Import

# %%
dg.data(file_path='portofino.csv', df_name='df')

# %%
# Code generated by DRAG
import numpy as np
import pandas as pd

df = pd.read_csv('portofino.csv')

# %% [markdown]
# ### Drag ask()

# %% [markdown]
# ##### Data Manipulation

# %%
dg.ask(data={'df':df}, question="How many homes have a swimming pool?", context=False)
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %% [markdown]
# ##### Add Column

# %%
dg.ask(data={'df':df}, question="Return a column where you indicate with True if there are at least 3 bedrooms otherwise False", context=False)

# %% [markdown]
# ##### Draw Chart

# %%
dg.ask(data={'df':df}, question="Draw a pie chart on the Three or More Bedrooms column", context=False)

# %% [markdown]
# ### Drag pipe()

# %%
dg.pipe(data={'df':df},
        question="filters for houses with swimming pools;\
        then filters for houses with vista mare;\
        then selects and prints only those priced below 500000")
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %% [markdown]
# ### Drag flow()

# %%
dg.flow_steps(flow='clean')
# Out:
# 0 - NaN values
#     Description: Handle missing values in the dataset.
#     Question: Write Python code to handle missing values in a dataset.
#
# 1 - Duplicates
#     Description: Identify and remove duplicate rows from the dataset.
#     Question: Generate Python code to identify and remove duplicate rows in a dataset.
#
# 2 - Standardisation
#     Description: Standardize the features by scaling them to have a mean of 0 and a standard deviation of 1.
#     Question: Create Python code to standardize features by scaling them to have a mean of 0 and a standard deviation of 1.
#
# 3 - Unrelevant columns
#     Description: Remove columns that are not relevant for the analysis or model training.
#     Question: Generate Python code to remove irrelevant columns from a dataset.
#
# 4 - Rename columns
#     Description: Rename columns to make them more descriptive or consistent.
#     Question: Write Python code to rename columns in a dataset to make them more descriptive or consistent.
#
# 5 - Remove outliers
#     Description: Identify and remove outliers from the dataset.
#     Question: Create Python code to identify and remove outliers from a dataset.

# %%
dg.flow(data={'df':df}, flow='clean')
# Out:
# {'NaN values': {'Description': 'Handle missing values in the dataset.', 'Question': 'Write Python code to handle missing values in a dataset.'}, 'Duplicates': {'Description': 'Identify and remove duplicate rows from the dataset.', 'Question': 'Generate Python code to identify and remove duplicate rows in a dataset.'}, 'Standardisation': {'Description': 'Standardize the features by scaling them to have a mean of 0 and a standard deviation of 1.', 'Question': 'Create Python code to standardize features by scaling them to have a mean of 0 and a standard deviation of 1.'}, 'Unrelevant columns': {'Description': 'Remove columns that are not relevant for the analysis or model training.', 'Question': 'Generate Python code to remove irrelevant columns from a dataset.'}, 'Remove outliers': {'Description': 'Identify and remove outliers from the dataset.', 'Question': 'Create Python code to identify and remove outliers from a dataset.'}}
